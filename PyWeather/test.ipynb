# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 623

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1


# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city
    #print(city_url)
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    record_count += 1

    # Run an API request for each of the cities
    
    try:
        # Make the API request
        response = requests.get(city_url)
        response.raise_for_status()  # Check for API errors

        # Parse the JSON and retrieve data
        data = response.json()
        city_data.append(data)

      # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

     # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = data['coord']['lat']
        city_lng = data['coord']['lon']
        city_max_temp = data['main']['temp_max']
        city_humidity = data['main']['humidity']
        city_clouds = data['clouds']['all']
        city_wind = data['wind']['speed']
        city_country = data['sys']['country']
        city_date = data['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | n'zeto
# Processing Record 2 of Set 1 | ngama
# Processing Record 3 of Set 1 | tiksi
# Processing Record 4 of Set 1 | copala
# Processing Record 5 of Set 1 | margaret river
# Processing Record 6 of Set 1 | baykalovo
# Processing Record 7 of Set 1 | edinburgh of the seven seas
# Processing Record 8 of Set 1 | shenkursk
# Processing Record 9 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | adamstown
# Processing Record 12 of Set 1 | papao
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | fortuna
# Processing Record 15 of Set 1 | avarua
# Processing Record 16 of Set 1 | bilibino
# Processing Record 17 of Set 1 | veydelevka
# Processing Record 18 of Set 1 | port-aux-francais
# Processing Record 19 of Set 1 | tarauaca
# Processing Record 20 of Set 1 | green river
# Processing Record 21 of Set 1 | blackmans bay
# Processing Record 22 of Set 1 | thunder bay
# Processing Record 23 of Set 1 | klaksvik
# Processing Record 24 of Set 1 | puerto natales
# Processing Record 25 of Set 1 | ettrick
# Processing Record 26 of Set 1 | minot
# Processing Record 27 of Set 1 | kutum
# Processing Record 28 of Set 1 | remire-montjoly
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | miracema do tocantins
# Processing Record 31 of Set 1 | bethel
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | brisas de zicatela
# Processing Record 34 of Set 1 | adis zemen
# Processing Record 35 of Set 1 | uturoa
# Processing Record 36 of Set 1 | fale old settlement
# Processing Record 37 of Set 1 | antofagasta
# Processing Record 38 of Set 1 | quinhamel
# Processing Record 39 of Set 1 | ambon
# Processing Record 40 of Set 1 | motueka
# Processing Record 41 of Set 1 | olonkinbyen
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | talnakh
# Processing Record 44 of Set 1 | kodinar
# Processing Record 45 of Set 1 | la passe
# Processing Record 46 of Set 1 | colonia
# Processing Record 47 of Set 1 | atafu village
# Processing Record 48 of Set 1 | kitami
# Processing Record 49 of Set 1 | kodiak
# Processing Record 50 of Set 1 | mirnyy
# Processing Record 0 of Set 2 | susuman
# Processing Record 1 of Set 2 | waitangi
# Processing Record 2 of Set 2 | baukau
# Processing Record 3 of Set 2 | howard springs
# Processing Record 4 of Set 2 | funafuti
# Processing Record 5 of Set 2 | west island
# Processing Record 6 of Set 2 | georgetown
# Processing Record 7 of Set 2 | northam
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | ushuaia
# Processing Record 10 of Set 2 | shurugwi
# Processing Record 11 of Set 2 | khandyga
# Processing Record 12 of Set 2 | mendoza
# Processing Record 13 of Set 2 | tsiombe
# Processing Record 14 of Set 2 | vadso
# Processing Record 15 of Set 2 | mariental
# Processing Record 16 of Set 2 | whitehorse
# Processing Record 17 of Set 2 | kitimat
# Processing Record 18 of Set 2 | dunkwa
# Processing Record 19 of Set 2 | ostersund
# Processing Record 20 of Set 2 | santa maria rayon
# Processing Record 21 of Set 2 | kodinsk
# Processing Record 22 of Set 2 | hawaiian paradise park
# Processing Record 23 of Set 2 | moncton
# Processing Record 24 of Set 2 | yuzhno-kurilsk
# Processing Record 25 of Set 2 | ilulissat
# Processing Record 26 of Set 2 | novyy urgal
# Processing Record 27 of Set 2 | fada
# Processing Record 28 of Set 2 | qaqortoq
# Processing Record 29 of Set 2 | lompoc
# Processing Record 30 of Set 2 | san antonio de pale
# Processing Record 31 of Set 2 | khorugh
# Processing Record 32 of Set 2 | iqaluit
# Processing Record 33 of Set 2 | badger
# Processing Record 34 of Set 2 | bethanie
# Processing Record 35 of Set 2 | tafuna
# Processing Record 36 of Set 2 | jamestown
# Processing Record 37 of Set 2 | smithers
# Processing Record 38 of Set 2 | gallivare
# City not found. Skipping...
# Processing Record 39 of Set 2 | lazaro cardenas
# Processing Record 40 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 41 of Set 2 | ponta delgada
# Processing Record 42 of Set 2 | puerto baquerizo moreno
# Processing Record 43 of Set 2 | loukhi
# Processing Record 44 of Set 2 | mashava
# Processing Record 45 of Set 2 | burang
# Processing Record 46 of Set 2 | grytviken
# Processing Record 47 of Set 2 | orumiyeh
# Processing Record 48 of Set 2 | utrik
# Processing Record 49 of Set 2 | vila velha
# Processing Record 0 of Set 3 | chiplun
# Processing Record 1 of Set 3 | aasiaat
# Processing Record 2 of Set 3 | laguna
# Processing Record 3 of Set 3 | yanam
# Processing Record 4 of Set 3 | flying fish cove
# Processing Record 5 of Set 3 | kone
# Processing Record 6 of Set 3 | port mathurin
# Processing Record 7 of Set 3 | stanley
# Processing Record 8 of Set 3 | whangarei
# Processing Record 9 of Set 3 | labuan
# Processing Record 10 of Set 3 | hammerfest
# Processing Record 11 of Set 3 | la'ie
# Processing Record 12 of Set 3 | pangkalpinang
# Processing Record 13 of Set 3 | gazojak
# Processing Record 14 of Set 3 | revda
# Processing Record 15 of Set 3 | qarazhal
# Processing Record 16 of Set 3 | fiambala
# Processing Record 17 of Set 3 | three points
# Processing Record 18 of Set 3 | praia da vitoria
# Processing Record 19 of Set 3 | tacna
# Processing Record 20 of Set 3 | ta`u
# Processing Record 21 of Set 3 | port elizabeth
# Processing Record 22 of Set 3 | pisco
# Processing Record 23 of Set 3 | papatowai
# Processing Record 24 of Set 3 | palmas
# Processing Record 25 of Set 3 | ribeira grande
# Processing Record 26 of Set 3 | kismayo
# Processing Record 27 of Set 3 | alamosa
# Processing Record 28 of Set 3 | kamphaeng phet
# Processing Record 29 of Set 3 | saipan
# Processing Record 30 of Set 3 | turuntayevo
# Processing Record 31 of Set 3 | invercargill
# Processing Record 32 of Set 3 | tura
# Processing Record 33 of Set 3 | constantia
# Processing Record 34 of Set 3 | praia
# Processing Record 35 of Set 3 | mahajanga
# Processing Record 36 of Set 3 | wailua homesteads
# Processing Record 37 of Set 3 | queenstown
# Processing Record 38 of Set 3 | cabo san lucas
# Processing Record 39 of Set 3 | kopargaon
# Processing Record 40 of Set 3 | lamu
# Processing Record 41 of Set 3 | ifakara
# Processing Record 42 of Set 3 | makokou
# Processing Record 43 of Set 3 | teni
# Processing Record 44 of Set 3 | dori
# Processing Record 45 of Set 3 | victorica
# Processing Record 46 of Set 3 | vorgashor
# Processing Record 47 of Set 3 | antonio enes
# Processing Record 48 of Set 3 | fuvahmulah
# City not found. Skipping...
# Processing Record 49 of Set 3 | dzhalagash
# Processing Record 0 of Set 4 | isafjordur
# Processing Record 1 of Set 4 | tolanaro
# Processing Record 2 of Set 4 | portland
# Processing Record 3 of Set 4 | inverurie
# Processing Record 4 of Set 4 | strathfieldsaye
# Processing Record 5 of Set 4 | ouesso
# Processing Record 6 of Set 4 | hamilton
# Processing Record 7 of Set 4 | nova vicosa
# Processing Record 8 of Set 4 | east ballina
# Processing Record 9 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 10 of Set 4 | port alfred
# Processing Record 11 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 12 of Set 4 | kiunga
# Processing Record 13 of Set 4 | new norfolk
# Processing Record 14 of Set 4 | hithadhoo
# Processing Record 15 of Set 4 | lagunas
# Processing Record 16 of Set 4 | bam
# Processing Record 17 of Set 4 | cockburn town
# Processing Record 18 of Set 4 | afaahiti
# Processing Record 19 of Set 4 | kavaratti
# Processing Record 20 of Set 4 | fort bragg
# Processing Record 21 of Set 4 | polyarnyy
# Processing Record 22 of Set 4 | homestead meadows south
# Processing Record 23 of Set 4 | mejit
# Processing Record 24 of Set 4 | shunyi
# Processing Record 25 of Set 4 | anabar
# City not found. Skipping...
# Processing Record 26 of Set 4 | elmendorf air force base
# City not found. Skipping...
# Processing Record 27 of Set 4 | jacmel
# Processing Record 28 of Set 4 | taoudenni
# Processing Record 29 of Set 4 | anadyr
# Processing Record 30 of Set 4 | kavak
# Processing Record 31 of Set 4 | kapa'a
# Processing Record 32 of Set 4 | ust'-kut
# Processing Record 33 of Set 4 | fasa
# Processing Record 34 of Set 4 | ust-nera
# Processing Record 35 of Set 4 | burela de cabo
# Processing Record 36 of Set 4 | knyaze-volkonskoye
# Processing Record 37 of Set 4 | carnarvon
# Processing Record 38 of Set 4 | akjoujt
# Processing Record 39 of Set 4 | charlottetown
# Processing Record 40 of Set 4 | keffi
# Processing Record 41 of Set 4 | longyearbyen
# Processing Record 42 of Set 4 | mount gambier
# Processing Record 43 of Set 4 | puerto deseado
# Processing Record 44 of Set 4 | lebu
# Processing Record 45 of Set 4 | marka
# Processing Record 46 of Set 4 | nuku'alofa
# Processing Record 47 of Set 4 | haiku-pauwela
# Processing Record 48 of Set 4 | thompson
# Processing Record 49 of Set 4 | angaur state
# Processing Record 0 of Set 5 | college
# Processing Record 1 of Set 5 | kariba
# Processing Record 2 of Set 5 | rantauprapat
# Processing Record 3 of Set 5 | alterosa
# Processing Record 4 of Set 5 | saldanha
# Processing Record 5 of Set 5 | stephenville
# Processing Record 6 of Set 5 | yazihan
# Processing Record 7 of Set 5 | enewetak
# Processing Record 8 of Set 5 | tual
# Processing Record 9 of Set 5 | huruta
# Processing Record 10 of Set 5 | kingston
# Processing Record 11 of Set 5 | bamboo flat
# Processing Record 12 of Set 5 | anloga
# Processing Record 13 of Set 5 | freetown
# Processing Record 14 of Set 5 | hadibu
# Processing Record 15 of Set 5 | charlottesville
# Processing Record 16 of Set 5 | klyuchi
# Processing Record 17 of Set 5 | gorontalo
# Processing Record 18 of Set 5 | poronaysk
# Processing Record 19 of Set 5 | severo-yeniseyskiy
# Processing Record 20 of Set 5 | hami
# Processing Record 21 of Set 5 | ketchikan
# Processing Record 22 of Set 5 | lorengau
# Processing Record 23 of Set 5 | coruripe
# Processing Record 24 of Set 5 | la huacana
# Processing Record 25 of Set 5 | ebon
# Processing Record 26 of Set 5 | mermoz boabab
# Processing Record 27 of Set 5 | ramona
# Processing Record 28 of Set 5 | levuka
# Processing Record 29 of Set 5 | riyadh
# Processing Record 30 of Set 5 | karratha
# Processing Record 31 of Set 5 | eilat
# Processing Record 32 of Set 5 | magadi
# Processing Record 33 of Set 5 | port saint john's
# Processing Record 34 of Set 5 | zhaotong
# Processing Record 35 of Set 5 | malpica
# Processing Record 36 of Set 5 | la ronge
# Processing Record 37 of Set 5 | bhitarwar
# Processing Record 38 of Set 5 | port hedland
# Processing Record 39 of Set 5 | manokwari
# Processing Record 40 of Set 5 | watsa
# Processing Record 41 of Set 5 | nagqu
# Processing Record 42 of Set 5 | iskateley
# Processing Record 43 of Set 5 | udachny
# Processing Record 44 of Set 5 | saynshand
# Processing Record 45 of Set 5 | nabire
# Processing Record 46 of Set 5 | lihue
# Processing Record 47 of Set 5 | kailua-kona
# Processing Record 48 of Set 5 | brenham
# Processing Record 49 of Set 5 | ashburton
# Processing Record 0 of Set 6 | santana
# Processing Record 1 of Set 6 | kirtland
# Processing Record 2 of Set 6 | tanki leendert
# City not found. Skipping...
# Processing Record 3 of Set 6 | tambura
# Processing Record 4 of Set 6 | matthew town
# Processing Record 5 of Set 6 | breckenridge
# Processing Record 6 of Set 6 | kamaishi
# Processing Record 7 of Set 6 | zhaozhou
# Processing Record 8 of Set 6 | saksaul'skiy
# City not found. Skipping...
# Processing Record 9 of Set 6 | sosnovo-ozerskoye
# Processing Record 10 of Set 6 | ma'an
# Processing Record 11 of Set 6 | chibougamau
# Processing Record 12 of Set 6 | sumbawa besar
# Processing Record 13 of Set 6 | tumayr
# Processing Record 14 of Set 6 | kruisfontein
# Processing Record 15 of Set 6 | st. john's
# Processing Record 16 of Set 6 | espargos
# City not found. Skipping...
# Processing Record 17 of Set 6 | coari
# Processing Record 18 of Set 6 | nova sintra
# Processing Record 19 of Set 6 | taroa
# Processing Record 20 of Set 6 | el calafate
# Processing Record 21 of Set 6 | hegang
# Processing Record 22 of Set 6 | al kiswah
# Processing Record 23 of Set 6 | el kala
# Processing Record 24 of Set 6 | aitape
# Processing Record 25 of Set 6 | vanino
# Processing Record 26 of Set 6 | beroroha
# Processing Record 27 of Set 6 | igarka
# Processing Record 28 of Set 6 | laikit, laikit ii (dimembe)
# Processing Record 29 of Set 6 | barranca
# Processing Record 30 of Set 6 | whyalla stuart
# City not found. Skipping...
# Processing Record 31 of Set 6 | turar ryskulov
# Processing Record 32 of Set 6 | tofol
# Processing Record 33 of Set 6 | ha giang
# Processing Record 34 of Set 6 | dalkola
# Processing Record 35 of Set 6 | trairi
# Processing Record 36 of Set 6 | mandan
# Processing Record 37 of Set 6 | nouadhibou
# Processing Record 38 of Set 6 | yelizovo
# Processing Record 39 of Set 6 | usinsk
# Processing Record 40 of Set 6 | sakaiminato
# Processing Record 41 of Set 6 | labrador city
# Processing Record 42 of Set 6 | chos malal
# Processing Record 43 of Set 6 | san jose del guaviare
# Processing Record 44 of Set 6 | dok kham tai
# Processing Record 45 of Set 6 | i-n-salah
# Processing Record 46 of Set 6 | nicosia
# Processing Record 47 of Set 6 | bayanhongor
# Processing Record 48 of Set 6 | pasuquin
# Processing Record 49 of Set 6 | dudinka
# Processing Record 0 of Set 7 | puerto armuelles
# Processing Record 1 of Set 7 | kununurra
# Processing Record 2 of Set 7 | torre de moncorvo
# Processing Record 3 of Set 7 | mayiladuthurai
# Processing Record 4 of Set 7 | kulia village
# City not found. Skipping...
# Processing Record 5 of Set 7 | taro
# Processing Record 6 of Set 7 | bardai
# Processing Record 7 of Set 7 | keflavik
# Processing Record 8 of Set 7 | kayangel
# Processing Record 9 of Set 7 | menongue
# Processing Record 10 of Set 7 | dhidhdhoo
# Processing Record 11 of Set 7 | howrah
# Processing Record 12 of Set 7 | calvinia
# Processing Record 13 of Set 7 | havre
# Processing Record 14 of Set 7 | gdansk
# Processing Record 15 of Set 7 | volterra
# Processing Record 16 of Set 7 | lichtenburg
# Processing Record 17 of Set 7 | najran
# Processing Record 18 of Set 7 | crane
# Processing Record 19 of Set 7 | kish
# Processing Record 20 of Set 7 | at taj
# Processing Record 21 of Set 7 | darnah
# Processing Record 22 of Set 7 | tadine
# Processing Record 23 of Set 7 | yeniseysk
# Processing Record 24 of Set 7 | fort st. john
# Processing Record 25 of Set 7 | pacific grove
# Processing Record 26 of Set 7 | linghai
# Processing Record 27 of Set 7 | serowe
# Processing Record 28 of Set 7 | cidreira
# Processing Record 29 of Set 7 | minacu
# City not found. Skipping...
# Processing Record 30 of Set 7 | galesong
# Processing Record 31 of Set 7 | dakoro
# Processing Record 32 of Set 7 | ulanhot
# Processing Record 33 of Set 7 | umm kaddadah
# Processing Record 34 of Set 7 | castillos
# Processing Record 35 of Set 7 | kudahuvadhoo
# Processing Record 36 of Set 7 | oxapampa
# Processing Record 37 of Set 7 | sao raimundo das mangabeiras
# Processing Record 38 of Set 7 | cofradia
# Processing Record 39 of Set 7 | emerald
# Processing Record 40 of Set 7 | el obeid
# Processing Record 41 of Set 7 | al hufuf
# Processing Record 42 of Set 7 | camden
# Processing Record 43 of Set 7 | peace river
# Processing Record 44 of Set 7 | huilong
# Processing Record 45 of Set 7 | bocas del toro
# Processing Record 46 of Set 7 | laojunmiao
# Processing Record 47 of Set 7 | kapuskasing
# Processing Record 48 of Set 7 | bonthe
# Processing Record 49 of Set 7 | conduaga
# Processing Record 0 of Set 8 | codrington
# Processing Record 1 of Set 8 | mandalgovi
# Processing Record 2 of Set 8 | saraktash
# Processing Record 3 of Set 8 | sorong
# Processing Record 4 of Set 8 | urengoy
# Processing Record 5 of Set 8 | gurupi
# Processing Record 6 of Set 8 | sitka
# Processing Record 7 of Set 8 | puerto escondido
# Processing Record 8 of Set 8 | rocky mountain house
# Processing Record 9 of Set 8 | gadzhiyevo
# Processing Record 10 of Set 8 | selkirk
# Processing Record 11 of Set 8 | jiagedaqi
# Processing Record 12 of Set 8 | andalgala
# Processing Record 13 of Set 8 | otjiwarongo
# Processing Record 14 of Set 8 | nuuk
# Processing Record 15 of Set 8 | peniche
# Processing Record 16 of Set 8 | atar
# Processing Record 17 of Set 8 | yamoto
# Processing Record 18 of Set 8 | la gi
# Processing Record 19 of Set 8 | contamana
# Processing Record 20 of Set 8 | inarajan village
# Processing Record 21 of Set 8 | hargeysa
# Processing Record 22 of Set 8 | concepcion del oro
# Processing Record 23 of Set 8 | al bardiyah
# Processing Record 24 of Set 8 | weno
# Processing Record 25 of Set 8 | bratsk
# Processing Record 26 of Set 8 | nguti
# Processing Record 27 of Set 8 | preston
# Processing Record 28 of Set 8 | sabha
# Processing Record 29 of Set 8 | xinyuan
# Processing Record 30 of Set 8 | jimenez
# Processing Record 31 of Set 8 | vryburg
# Processing Record 32 of Set 8 | oistins
# Processing Record 33 of Set 8 | stuttgart
# Processing Record 34 of Set 8 | ghat
# Processing Record 35 of Set 8 | pathein
# Processing Record 36 of Set 8 | yinzhu
# Processing Record 37 of Set 8 | prince albert
# Processing Record 38 of Set 8 | vila franca do campo
# Processing Record 39 of Set 8 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 40 of Set 8 | zouerate
# Processing Record 41 of Set 8 | kidal
# Processing Record 42 of Set 8 | kralendijk
# Processing Record 43 of Set 8 | rio grande
# Processing Record 44 of Set 8 | naze
# Processing Record 45 of Set 8 | taulaga
# Processing Record 46 of Set 8 | corner brook
# Processing Record 47 of Set 8 | mahanoro
# Processing Record 48 of Set 8 | bhag
# Processing Record 49 of Set 8 | broome
# Processing Record 0 of Set 9 | zardob
# Processing Record 1 of Set 9 | qarqaraly
# Processing Record 2 of Set 9 | santyoku
# Processing Record 3 of Set 9 | damboa
# Processing Record 4 of Set 9 | mana
# Processing Record 5 of Set 9 | thohoyandou
# Processing Record 6 of Set 9 | kalmunai
# Processing Record 7 of Set 9 | monghyr
# Processing Record 8 of Set 9 | amga
# Processing Record 9 of Set 9 | kapan
# Processing Record 10 of Set 9 | argo
# Processing Record 11 of Set 9 | nagaoka
# Processing Record 12 of Set 9 | basoko
# Processing Record 13 of Set 9 | salinopolis
# Processing Record 14 of Set 9 | jabat
# Processing Record 15 of Set 9 | nemuro
# Processing Record 16 of Set 9 | gagnoa
# Processing Record 17 of Set 9 | ashkasham
# Processing Record 18 of Set 9 | ocean pointe
# City not found. Skipping...
# Processing Record 19 of Set 9 | sanctuary point
# Processing Record 20 of Set 9 | plettenberg bay
# Processing Record 21 of Set 9 | shubarkuduk
# Processing Record 22 of Set 9 | pandan
# Processing Record 23 of Set 9 | dombarovskiy
# Processing Record 24 of Set 9 | tuba city
# Processing Record 25 of Set 9 | san antonio
# Processing Record 26 of Set 9 | saeby
# Processing Record 27 of Set 9 | fisterra
# Processing Record 28 of Set 9 | hasaki
# Processing Record 29 of Set 9 | del rio
# Processing Record 30 of Set 9 | mount isa
# Processing Record 31 of Set 9 | alofi
# Processing Record 32 of Set 9 | cheremukhovo
# Processing Record 33 of Set 9 | vilyuchinsk
# Processing Record 34 of Set 9 | harnai
# Processing Record 35 of Set 9 | coquimbo
# Processing Record 36 of Set 9 | conceicao da barra
# Processing Record 37 of Set 9 | alo
# Processing Record 38 of Set 9 | puerto san carlos
# City not found. Skipping...
# Processing Record 39 of Set 9 | mulchen
# Processing Record 40 of Set 9 | kuna
# Processing Record 41 of Set 9 | wotho
# Processing Record 42 of Set 9 | margate
# Processing Record 43 of Set 9 | nizhnesortymskiy
# Processing Record 44 of Set 9 | al fuwayliq
# Processing Record 45 of Set 9 | kill devil hills
# Processing Record 46 of Set 9 | port lincoln
# Processing Record 47 of Set 9 | tobelo
# Processing Record 48 of Set 9 | kuragino
# Processing Record 49 of Set 9 | salavat
# Processing Record 0 of Set 10 | saint-philippe
# Processing Record 1 of Set 10 | tevriz
# Processing Record 2 of Set 10 | san agustin de valle fertil
# Processing Record 3 of Set 10 | 'ohonua
# City not found. Skipping...
# Processing Record 4 of Set 10 | vila do maio
# Processing Record 5 of Set 10 | staraya russa
# Processing Record 6 of Set 10 | selfoss
# Processing Record 7 of Set 10 | kogalym
# Processing Record 8 of Set 10 | kolokani
# Processing Record 9 of Set 10 | glace bay
# Processing Record 10 of Set 10 | harstad
# Processing Record 11 of Set 10 | mbaiki
# Processing Record 12 of Set 10 | lata
# Processing Record 13 of Set 10 | chinde
# Processing Record 14 of Set 10 | itaueira
# Processing Record 15 of Set 10 | hilo
# Processing Record 16 of Set 10 | homun
# Processing Record 17 of Set 10 | lent'ekhi
# Processing Record 18 of Set 10 | karema
# Processing Record 19 of Set 10 | lambarene
# Processing Record 20 of Set 10 | okhotsk
# Processing Record 21 of Set 10 | villa gesell
# Processing Record 22 of Set 10 | kimbe
# Processing Record 23 of Set 10 | mil'kovo
# Processing Record 24 of Set 10 | tidjikja
# Processing Record 25 of Set 10 | neryungri
# Processing Record 26 of Set 10 | san patricio
# Processing Record 27 of Set 10 | zagora
# Processing Record 28 of Set 10 | baoding
# Processing Record 29 of Set 10 | seogwipo
# City not found. Skipping...
# Processing Record 30 of Set 10 | miasskoye
# Processing Record 31 of Set 10 | troitsko-pechorsk
# Processing Record 32 of Set 10 | kargalinskaya
# Processing Record 33 of Set 10 | leua
# Processing Record 34 of Set 10 | newman
# Processing Record 35 of Set 10 | chivhu
# Processing Record 36 of Set 10 | manturovo
# Processing Record 37 of Set 10 | mul
# Processing Record 38 of Set 10 | gangapur
# Processing Record 39 of Set 10 | centralia
# Processing Record 40 of Set 10 | kerikeri
# Processing Record 41 of Set 10 | antsirabe afovoany
# City not found. Skipping...
# Processing Record 42 of Set 10 | blatna
# Processing Record 43 of Set 10 | san clemente
# Processing Record 44 of Set 10 | basco
# Processing Record 45 of Set 10 | gremyachinsk
# Processing Record 46 of Set 10 | ancud
# Processing Record 47 of Set 10 | kelaat mgouna
# City not found. Skipping...
# Processing Record 48 of Set 10 | nephi
# Processing Record 49 of Set 10 | tefe
# Processing Record 0 of Set 11 | oranjestad
# Processing Record 1 of Set 11 | clairton
# Processing Record 2 of Set 11 | qamdo
# Processing Record 3 of Set 11 | tazacorte
# Processing Record 4 of Set 11 | palikir - national government center
# Processing Record 5 of Set 11 | ekpoma
# Processing Record 6 of Set 11 | zhezqazghan
# Processing Record 7 of Set 11 | cradock
# Processing Record 8 of Set 11 | tlapa de comonfort
# Processing Record 9 of Set 11 | miranda do douro
# Processing Record 10 of Set 11 | troitsk
# Processing Record 11 of Set 11 | acarau
# Processing Record 12 of Set 11 | tabriz
# Processing Record 13 of Set 11 | malabar
# Processing Record 14 of Set 11 | ceeldheer
# Processing Record 15 of Set 11 | haenam
# Processing Record 16 of Set 11 | novodvinsk
# Processing Record 17 of Set 11 | amungan
# Processing Record 18 of Set 11 | soio
# Processing Record 19 of Set 11 | kolonia
# Processing Record 20 of Set 11 | hassi messaoud
# Processing Record 21 of Set 11 | sabang
# Processing Record 22 of Set 11 | dubbo
# Processing Record 23 of Set 11 | ghadamis
# Processing Record 24 of Set 11 | young
# Processing Record 25 of Set 11 | blitar
# Processing Record 26 of Set 11 | nanzhang chengguanzhen
# Processing Record 27 of Set 11 | kuala belait
# Processing Record 28 of Set 11 | port macquarie
# Processing Record 29 of Set 11 | ust'-barguzin
# Processing Record 30 of Set 11 | mayna
# Processing Record 31 of Set 11 | tamanrasset
# Processing Record 32 of Set 11 | geraldton
# Processing Record 33 of Set 11 | oranjemund
# Processing Record 34 of Set 11 | dunedin
# Processing Record 35 of Set 11 | shabqadar
# Processing Record 36 of Set 11 | elizabeth city
# Processing Record 37 of Set 11 | inverell
# Processing Record 38 of Set 11 | kulhudhuffushi
# Processing Record 39 of Set 11 | calama
# Processing Record 40 of Set 11 | riohacha
# Processing Record 41 of Set 11 | forbes
# Processing Record 42 of Set 11 | mount pearl
# Processing Record 43 of Set 11 | natal
# Processing Record 44 of Set 11 | chililabombwe
# Processing Record 45 of Set 11 | alesund
# Processing Record 46 of Set 11 | nema
# Processing Record 47 of Set 11 | arraial do cabo
# Processing Record 48 of Set 11 | kurtamysh
# Processing Record 49 of Set 11 | holualoa
# Processing Record 0 of Set 12 | elliot lake
# Processing Record 1 of Set 12 | ingraj bazar
# Processing Record 2 of Set 12 | santa marta
# Processing Record 3 of Set 12 | saudarkrokur
# Processing Record 4 of Set 12 | san andres
# Processing Record 5 of Set 12 | wenchang
# Processing Record 6 of Set 12 | bannockburn
# Processing Record 7 of Set 12 | sinjai
# Processing Record 8 of Set 12 | luwuk
# Processing Record 9 of Set 12 | basingstoke
# Processing Record 10 of Set 12 | ad dilam
# Processing Record 11 of Set 12 | chizhou
# Processing Record 12 of Set 12 | drummondville
# Processing Record 13 of Set 12 | saryaghash
# Processing Record 14 of Set 12 | ouro branco
# Processing Record 15 of Set 12 | nar'yan-mar
# Processing Record 16 of Set 12 | north bondi
# Processing Record 17 of Set 12 | bismarck
# Processing Record 18 of Set 12 | benjamin constant
# Processing Record 19 of Set 12 | sao joao da barra
# Processing Record 20 of Set 12 | seydi
# Processing Record 21 of Set 12 | koregaon
# Processing Record 22 of Set 12 | mondim de basto
# Processing Record 23 of Set 12 | ca mau
# Processing Record 24 of Set 12 | devinuwara
# City not found. Skipping...
# Processing Record 25 of Set 12 | quepos
# Processing Record 26 of Set 12 | mukalla
# Processing Record 27 of Set 12 | mahalapye
# Processing Record 28 of Set 12 | rabaul
# Processing Record 29 of Set 12 | richards bay
# Processing Record 30 of Set 12 | rusape
# Processing Record 31 of Set 12 | kyshtovka
# Processing Record 32 of Set 12 | yicheng
# Processing Record 33 of Set 12 | chillicothe
# Processing Record 34 of Set 12 | ishinomaki
# Processing Record 35 of Set 12 | pantai cenang
# City not found. Skipping...
# Processing Record 36 of Set 12 | hatillo
# Processing Record 37 of Set 12 | moreira sales
# Processing Record 38 of Set 12 | farasan
# Processing Record 39 of Set 12 | alice springs
# Processing Record 40 of Set 12 | mach
# Processing Record 41 of Set 12 | papar
# Processing Record 42 of Set 12 | bengkulu
# Processing Record 43 of Set 12 | viedma
# Processing Record 44 of Set 12 | mumbai
# Processing Record 45 of Set 12 | uttarkashi
# Processing Record 46 of Set 12 | kataragama
# City not found. Skipping...
# Processing Record 47 of Set 12 | rongelap
# Processing Record 48 of Set 12 | kupang
# Processing Record 49 of Set 12 | san julian
# Processing Record 0 of Set 13 | fonte boa
# Processing Record 1 of Set 13 | kant
# Processing Record 2 of Set 13 | yabelo
# Processing Record 3 of Set 13 | plastun
# Processing Record 4 of Set 13 | sinabang
# Processing Record 5 of Set 13 | berezovyy
# Processing Record 6 of Set 13 | gueltat zemmour
# City not found. Skipping...
# Processing Record 7 of Set 13 | santiago de cao
# Processing Record 8 of Set 13 | island harbour
# Processing Record 9 of Set 13 | labytnangi
# Processing Record 10 of Set 13 | genhe
# Processing Record 11 of Set 13 | thal
# Processing Record 12 of Set 13 | iquique
# Processing Record 13 of Set 13 | jumla
# Processing Record 14 of Set 13 | andradas
# Processing Record 15 of Set 13 | wakema
# Processing Record 16 of Set 13 | carutapera
# Processing Record 17 of Set 13 | fiditi
# Processing Record 18 of Set 13 | rabo de peixe
# Processing Record 19 of Set 13 | kukawa
# Processing Record 20 of Set 13 | vizinga
# Processing Record 21 of Set 13 | panjab
# Processing Record 22 of Set 13 | rodolfo sanchez taboada
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
record_count = city_data_df.count()
print(record_count)

# Display sample data
sample_data = city_data_df.head()
print(sample_data)
# Out:
# coord         599
# weather       599
# base          599
# main          599
# visibility    599
# wind          599
# clouds        599
# dt            599
# sys           599
# timezone      599
# id            599
# name          599
# cod           599
# rain           86
# snow            4
# City           24
# Lat            24
# Lng            24
# Max Temp       24
# Humidity       24
# Cloudiness     24
# Wind Speed     24
# Country        24
# Date           24
# dtype: int64
#                                coord  \
# 0   {'lon': 12.8666, 'lat': -7.2312}
# 1   {'lon': 17.1667, 'lat': 11.7833}
# 2  {'lon': 128.8694, 'lat': 71.6872}
# 3    {'lon': -98.9833, 'lat': 16.65}
# 4   {'lon': 115.0667, 'lat': -33.95}
#
#                                              weather      base  \
# 0  [{'id': 802, 'main': 'Clouds', 'description': ...  stations
# 1  [{'id': 803, 'main': 'Clouds', 'description': ...  stations
# 2  [{'id': 801, 'main': 'Clouds', 'description': ...  stations
# 3  [{'id': 801, 'main': 'Clouds', 'description': ...  stations
# 4  [{'id': 800, 'main': 'Clear', 'description': '...  stations
#
#                                                 main  visibility  \
# 0  {'temp': 294.88, 'feels_like': 295.41, 'temp_m...     10000.0
# 1  {'temp': 304.94, 'feels_like': 306.9, 'temp_mi...     10000.0
# 2  {'temp': 279.61, 'feels_like': 277.08, 'temp_m...     10000.0
# 3  {'temp': 306.53, 'feels_like': 312.19, 'temp_m...     10000.0
# 4  {'temp': 284.77, 'feels_like': 283.95, 'temp_m...     10000.0
#
#                                         wind       clouds            dt  \
# 0  {'speed': 3.87, 'deg': 215, 'gust': 6.23}  {'all': 38}  1.689966e+09
# 1     {'speed': 2, 'deg': 134, 'gust': 2.62}  {'all': 82}  1.689966e+09
# 2  {'speed': 3.52, 'deg': 194, 'gust': 3.98}  {'all': 21}  1.689965e+09
# 3  {'speed': 4.94, 'deg': 225, 'gust': 4.29}  {'all': 17}  1.689966e+09
# 4  {'speed': 1.38, 'deg': 250, 'gust': 1.99}   {'all': 1}  1.689965e+09
#
#                                                  sys  timezone  ...  snow  \
# 0  {'country': 'AO', 'sunrise': 1689916923, 'suns...    3600.0  ...   NaN
# 1  {'country': 'TD', 'sunrise': 1689914158, 'suns...    3600.0  ...   NaN
# 2       {'country': 'RU', 'sunrise': 0, 'sunset': 0}   32400.0  ...   NaN
# 3  {'country': 'MX', 'sunrise': 1689941566, 'suns...  -21600.0  ...   NaN
# 4  {'country': 'AU', 'sunrise': 1689981574, 'suns...   28800.0  ...   NaN
#
#   City  Lat Lng Max Temp Humidity  Cloudiness  Wind Speed  Country  Date
# 0  NaN  NaN NaN      NaN      NaN         NaN         NaN      NaN   NaN
# 1  NaN  NaN NaN      NaN      NaN         NaN         NaN      NaN   NaN
# 2  NaN  NaN NaN      NaN      NaN         NaN         NaN      NaN   NaN
# 3  NaN  NaN NaN      NaN      NaN         NaN         NaN      NaN   NaN
# 4  NaN  NaN NaN      NaN      NaN         NaN         NaN      NaN   NaN
#
# [5 rows x 24 columns]

# %%
# Show Record Count
city_data_df.count()

# %%
# Display sample data
city_data_df.head()

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import linregress

# Define the function to create a linear regression plot
def linear_regression_plot(x, y, x_label, y_label, title):
    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = linregress(x, y)

    # Calculate the regression line values
    regression_line = slope * x + intercept

    # Create the scatter plot
    plt.scatter(x, y, edgecolors="black", alpha=0.7)
    plt.plot(x, regression_line, color="red", label="Regression Line")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)

    # Display the correlation coefficient in the plot
    plt.annotate(f"Correlation: {r_value:.2f}", (min(x), max(y)), xytext=(10, -15), textcoords="offset points",
                 fontsize=10, color="blue")

    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Load the city data from the CSV file
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data for Northern Hemisphere
northern_hemi_df.head()

# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data for Southern Hemisphere
southern_hemi_df.head()

# Temperature vs. Latitude Linear Regression Plot - Northern Hemisphere
linear_regression_plot(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"],
                       "Latitude", "Max Temperature (°C)", "Temperature vs. Latitude (Northern Hemisphere)")

# Temperature vs. Latitude Linear Regression Plot - Southern Hemisphere
linear_regression_plot(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"],
                       "Latitude", "Max Temperature (°C)", "Temperature vs. Latitude (Southern Hemisphere)")

# Humidity vs. Latitude Linear Regression Plot - Northern Hemisphere
linear_regression_plot(northern_hemi_df["Lat"], northern_hemi_df["Humidity"],
                       "Latitude", "Humidity (%)", "Humidity vs. Latitude (Northern Hemisphere)")

# Humidity vs. Latitude Linear Regression Plot - Southern Hemisphere
linear_regression_plot(southern_hemi_df["Lat"], southern_hemi_df["Humidity"],
                       "Latitude", "Humidity (%)", "Humidity vs. Latitude (Southern Hemisphere)")

# Cloudiness vs. Latitude Linear Regression Plot - Northern Hemisphere
linear_regression_plot(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"],
                       "Latitude", "Cloudiness (%)", "Cloudiness vs. Latitude (Northern Hemisphere)")

# Cloudiness vs. Latitude Linear Regression Plot - Southern Hemisphere
linear_regression_plot(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"],
                       "Latitude", "Cloudiness (%)", "Cloudiness vs. Latitude (Southern Hemisphere)")

# Wind Speed vs. Latitude Linear Regression Plot - Northern Hemisphere
linear_regression_plot(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"],
                       "Latitude", "Wind Speed (meter/sec)", "Wind Speed vs. Latitude (Northern Hemisphere)")

# Wind Speed vs. Latitude Linear Regression Plot - Southern Hemisphere
linear_regression_plot(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"],
                       "Latitude", "Wind Speed (meter/sec)", "Wind Speed vs. Latitude (Southern Hemisphere)")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
